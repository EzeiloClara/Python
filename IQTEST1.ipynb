# %%
mentalage = 0

question_prompt = {
    'Q1': ['Stupid', 'Dumb','Smart','Idiotic'],
    'Q2': [45, 41, 40, 46],
    'Q3': ['Rhinoceri', 'Rhinoceroses', 'Rhinocery', 'Rhinocerosi'],
    'Q4': ['Appenda', 'Appendixes', 'Appendices', 'Appendix'],
    'Q5': ['Octupuses', 'Octupusses', 'Octupa', 'Octupi'],
    'Q6': ['Continuing is better than quitting with something', 'Someone who does not settle in one place does not prosper', 'Experience is growing over the years', 'Moving parts do not rust'],
    'Q7': [5, 6, 7, 8],
    'Q8': ['Monday', 'Tuesday'],
    'Q9': [206, -206, 306, -18416],
    'Q10':['sleep', 'nap', 'dream', 'walk'] 
}
answer= input('Which word is different from the rest:')
if answer == question_prompt['Q1'][2]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = int(input(' A Zoo has 41 animals, if 6 are dead, then how many animals are left?:'))
if answer == question_prompt['Q2'][1]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = input(' What is the plural of rhinoceros?:')
if answer == question_prompt['Q3'][0]:
    mentalage = mentalage +2
else: 
    mentalage = mentalage +0
    
answer = input('What is the plural of appendix?:')
if answer == question_prompt['Q4'][2]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = input('What is the plural of Octupus?')
if mentalage == question_prompt['Q5'][3]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = input(' What is the meaning of the saying \"A rolling stone gathers no moss\"?')
if answer == question_prompt['Q6'][1]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = int(input('Which number should be on the dots?\n27 9 18 6 12 4 ...:'))
if answer == question_prompt['Q7'][3]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = input('Tomorrow is Tuesday, which day was it in 15 days but 3 weeks ago?:')
if answer == question_prompt['Q8'][1]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = int(input('What is the result of this sum?\n16 * 63 - 1214:'))
if answer == question_prompt['Q9'][1]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    
answer = input(' Marathon is to race as Hibernation is to?')
if answer == question_prompt['Q10'][0]:
    mentalage = mentalage +2
else:
    mentalage = mentalage +0
    

    

ca = int(input('Please provide your age: '))
iq = (mentalage/ca) * 100
print(f'Your IQ is {iq}')
        
    
    
    
def ranking(iq):
    if iq >= 130:
        print('Very gifted')
    elif 120 < iq < 130:
        print('Gifted')
    elif 110 < iq < 121:
        print('Above average')
    elif 89 < iq < 111:
        print('Average')
    elif 79 < iq < 90:
        print('Below average')
    else:
        print('Cognitively impared')
            
ranking(iq)
# Out:
# Which word is different from the rest:smart
#  A Zoo has 41 animals, if 6 are dead, then how many animals are left?:41
#  What is the plural of rhinoceros?:rhinoceri
# What is the plural of appendix?:appendices
# What is the plural of Octupus?octupi
#  What is the meaning of the saying "A rolling stone gathers no moss"?mehh
# Which number should be on the dots?
# 27 9 18 6 12 4 ...:8
# Tomorrow is Tuesday, which day was it in 15 days but 3 weeks ago?:Tuesday
# What is the result of this sum?
# 16 * 63 - 1214:-206
#  Marathon is to race as Hibernation is to?sleep
# Please provide your age: 10
# Your IQ is 100.0
# Average

# %%
a
c
d
b
d
b
b
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9ac6b1095403> in <module>
# ----> 1 a
#       2 c
#       3 d
#       4 b
#       5 d
#
# NameError: name 'a' is not defined

# %%
def test_score():
    score = 0
    for question in questions:
        mentalage = input(question.prompt)
        if mentalage == question.answer:
            score += 1
    chronicle_age = input(age)
    iqscore = mentalage/chronicle_age * 100
    print(f'Your IQ test score is {iqscore} ')
